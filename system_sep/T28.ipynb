# %%
import predicsenseIB
import datetime
import zmq
import pandas as pd

conn = predicsenseIB.tpqibcon()

spy_contract = conn.create_contract('SPY', 'STK', 'SMART', 'SMART', 'USD')

context = zmq.Context()

# publishing for ML and plotly
socket_pub = context.socket(zmq.PUB)
socket_pub.bind('tcp://127.0.0.1:7000')

# publishing for acount, holding and trading info
socket_pub1 = context.socket(zmq.PUB)
socket_pub1.bind('tcp://127.0.0.1:7020')

# Subscribing to forwarder for trading
port = "7010"
socket_sub = context.socket(zmq.SUB)
socket_sub.connect("tcp://localhost:%s" % port)
socket_sub.setsockopt_string(zmq.SUBSCRIBE, u'SPY')

field = ['lastTimestamp', 'askPrice', 'askSize',
         'bidPrice', 'bidSize',
         'low', 'high', 'close',
         'volume', 'lastPrice', 'lastSize', 'halted']
# Out:
# Server Version: 76
# TWS Time at connection:20171002 19:07:13 IST

# %%
# for streaming market data
def send_tick(field, value):
    bid_price = ''
    bid_size=''
    ask_price=''
    ask_size=''
    df = pd.DataFrame()
    
   
    if field == 'bidPrice':
        bid_price = value
        bid_size=0
        ask_price=0
        ask_size=0
        msg = 'SPY %s %s %s %s' %(bid_price,bid_size,ask_price,ask_size)
        #print(msg)
        socket_pub.send_string(msg)
        
    if field == 'bidSize':
        bid_price = 0
        bid_size= value
        ask_price=0
        ask_size=0
        msg = 'SPY %s %s %s %s' %(bid_price,bid_size,ask_price,ask_size)
        #print(msg)
        socket_pub.send_string(msg)
        
    if field == 'askPrice':
        bid_price = 0
        bid_size= 0
        ask_price =value
        ask_size=0
        msg = 'SPY %s %s %s %s' %(bid_price,bid_size,ask_price,ask_size)
        #print(msg)
        socket_pub.send_string(msg)

    if field == 'askSize':
        bid_price = 0
        bid_size= 0
        ask_price =0
        ask_size=value
        msg = 'SPY %s %s %s %s' %(bid_price,bid_size,ask_price,ask_size)
        #print(msg)
        socket_pub.send_string(msg)


request_id = conn.request_market_data(spy_contract, send_tick)        
        
#if __name__ == '__main__':
#    request_id = conn.request_market_data(spy_contract, send_bid_price)

#conn.cancel_market_data(request_id)
#conn.close()
# Out:
# Server Error: Requested market data is not subscribed.Delayed market data is available.Error&BEST/STK/Top&BEST/STK/Top
# Server Error: Market data farm connection is broken:usfuture
# Server Error: Market data farm connection is broken:hfarm
# Server Error: Market data farm connection is broken:jfarm
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: Market data farm connection is OK:usfuture
# Server Error: Market data farm connection is OK:jfarm
# Server Error: Market data farm connection is OK:hfarm
# Server Error: Market data farm connection is broken:secdefus
# Server Error: Market data farm connection is broken:usfarm
# Server Error: Market data farm connection is broken:eufarm
# Server Error: Market data farm connection is OK:eufarm
# Server Error: Market data farm connection is broken:usfarm.us
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is OK:ushmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: Market data farm connection is OK:usfarm
# Server Error: Market data farm connection is OK:secdefus
# Server Error: HMDS data farm connection is OK:euhmds
# Server Error: Market data farm connection is broken:cashfarm
# Server Error: Market data farm connection is OK:usfarm.us
# Server Error: HMDS data farm connection is OK:cashhmds
# Server Error: Market data farm connection is OK:cashfarm
# Server Error: HMDS data farm connection is OK:fundfarm
# Server Error: Connectivity between IB and Trader Workstation has been lost.
# Server Error: Connectivity between IB and Trader Workstation has been restored - data maintained.
# Server Error: Market data farm connection is broken:jfarm
# Server Error: Market data farm connection is OK:jfarm
# Server Error: Market data farm connection is broken:hfarm
# Server Error: Market data farm connection is OK:hfarm
# Server Error: Market data farm connection is broken:cashfarm
# Server Error: Market data farm connection is OK:cashfarm
# Server Error: Market data farm connection is broken:cashfarm
# Server Error: Market data farm connection is OK:cashfarm
# Server Error: Market data farm connection is broken:hfarm
# Server Error: Market data farm connection is OK:hfarm
# Server Error: Market data farm connection is broken:hfarm
# Server Error: Market data farm connection is OK:hfarm
# Server Error: unpack requires a bytes object of length 1
# Bye.

# %%
#conn.cancel_market_data(request_id)
#conn.close()

# %%
pos=conn.req_positions()
average=pos[pos['sym']=='SPY'].tail(1).avgCost
quantity=pos[pos['sym']=='SPY'].tail(1).quantity
# Out:
# Server Error: Market data farm connection is broken:jfarm
# Server Error: Market data farm connection is OK:jfarm
# Server Error: Market data farm connection is broken:cashfarm
# Server Error: Market data farm connection is broken:cashfarm
# Server Error: Market data farm connection is broken:cashfarm
# Server Error: Market data farm connection is broken:cashfarm
# Server Error: Market data farm connection is OK:cashfarm
# Server Error: Market data farm connection is broken:hfarm
# Server Error: Market data farm connection is OK:hfarm
# Server Error: Market data farm connection is broken:hfarm
# Server Error: Market data farm connection is OK:hfarm
# Server Error: Market data farm connection is broken:hfarm
# Server Error: Market data farm connection is OK:hfarm
# Server Error: Requested market data is not subscribed.Delayed market data is available.Error&BEST/STK/Top&BEST/STK/Top
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: unpack requires a bytes object of length 1
# Bye.

# %% [markdown]
# ## TRADING

# %% [markdown]
# #### Subscription to port:7010
