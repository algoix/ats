# %% [markdown]
# ### Collecting from IB, publishing and subscription to forward

# %%
#import tpqib
import predicsenseIB
import datetime
import zmq
import pandas as pd

conn = predicsenseIB.tpqibcon()

spy_contract = conn.create_contract('SPY', 'STK', 'SMART', 'SMART', 'USD')

context = zmq.Context()

# publishing for ML and plotly
socket_pub = context.socket(zmq.PUB)
socket_pub.bind('tcp://127.0.0.1:7000')

# publishing for acount, holding and trading info
socket_pub1 = context.socket(zmq.PUB)
socket_pub1.bind('tcp://127.0.0.1:7020')

# Subscribing to forwarder for trading
port = "7010"
socket_sub = context.socket(zmq.SUB)
socket_sub.connect("tcp://localhost:%s" % port)
socket_sub.setsockopt_string(zmq.SUBSCRIBE, u'SPY')

field = ['lastTimestamp', 'askPrice', 'askSize',
         'bidPrice', 'bidSize',
         'low', 'high', 'close',
         'volume', 'lastPrice', 'lastSize', 'halted']
#,'position','accountSummary'
# Out:
# Server Version: 76
# TWS Time at connection:20170916 01:47:39 IST

# %%
# for streaming market data
def send_tick(field, value):
    bid_price = ''
    bid_size=''
    ask_price=''
    ask_size=''
    df = pd.DataFrame()
    
    if field == 'bidPrice':
        bid_price = value
        bid_size=0
        ask_price=0
        ask_size=0
        msg = 'SPY %s %s %s %s' %(bid_price,bid_size,ask_price,ask_size)
        #print(msg)
        socket_pub.send_string(msg)
        
    if field == 'bidSize':
        bid_price = 0
        bid_size= value
        ask_price=0
        ask_size=0
        msg = 'SPY %s %s %s %s' %(bid_price,bid_size,ask_price,ask_size)
        #print(msg)
        socket_pub.send_string(msg)
        
    if field == 'askPrice':
        bid_price = 0
        bid_size= 0
        ask_price =value
        ask_size=0
        msg = 'SPY %s %s %s %s' %(bid_price,bid_size,ask_price,ask_size)
        #print(msg)
        socket_pub.send_string(msg)

    if field == 'askSize':
        bid_price = 0
        bid_size= 0
        ask_price =0
        ask_size=value
        msg = 'SPY %s %s %s %s' %(bid_price,bid_size,ask_price,ask_size)
        #print(msg)
        socket_pub.send_string(msg)


request_id = conn.request_market_data(spy_contract, send_tick)        
        
#if __name__ == '__main__':
#    request_id = conn.request_market_data(spy_contract, send_bid_price)

#conn.cancel_market_data(request_id)
#conn.close()

# %%
conn.cancel_market_data(request_id)
conn.close()
# Out:
# Bye.

# %%
#pos=conn.req_positions().to_string(header=False,index=False,index_names=False).split('\n')
#socket_pub1.send_string(pos[-1])

# %%
pos=conn.req_positions()

# %%
conn.req_positions()
# Out:
#       avgCost  cur   quantity  sym
# 1  250.090000  USD      800.0  SPY
# 1    1.311037  CAD  1130078.0  USD
# 1  250.090000  USD      800.0  SPY
# 1    1.311037  CAD  1130078.0  USD
# 1  250.090000  USD      800.0  SPY
# 1    1.311037  CAD  1130078.0  USD
# 1  250.090000  USD      800.0  SPY
# 1    1.311037  CAD  1130078.0  USD
# 1  250.090000  USD      800.0  SPY
# 1    1.311037  CAD  1130078.0  USD
# 1  250.090000  USD      800.0  SPY
# 1    1.311037  CAD  1130078.0  USD

# %%
average=pos[pos['sym']=='SPY'].tail(1).avgCost

# %%
quantity=pos[pos['sym']=='SPY'].tail(1).quantity
# Out:
# Server Error: Market data farm connection is broken:jfarm
# Server Error: Market data farm connection is OK:jfarm
# Server Error: Market data farm connection is broken:cashfarm
# Server Error: Market data farm connection is broken:cashfarm
# Server Error: Market data farm connection is broken:cashfarm
# Server Error: Market data farm connection is OK:cashfarm
# Server Error: Market data farm connection is broken:cashfarm
# Server Error: Market data farm connection is OK:cashfarm
# Server Error: Market data farm connection is broken:hfarm
# Server Error: Market data farm connection is OK:hfarm
# Server Error: Market data farm connection is broken:hfarm
# Server Error: Market data farm connection is OK:hfarm
# Server Error: Market data farm connection is broken:hfarm
# Server Error: Market data farm connection is OK:hfarm
# Server Error: Market data farm connection is broken:hfarm
# Server Error: Market data farm connection is OK:hfarm
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is OK:fundfarm
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: HMDS data farm connection is broken:ushmds.us
# Server Error: HMDS data farm connection is broken:cashhmds
# Server Error: HMDS data farm connection is broken:euhmds
# Server Error: HMDS data farm connection is broken:fundfarm
# Server Error: HMDS data farm connection is broken:ushmds
# Server Error: unpack requires a bytes object of length 1
# Bye.

# %% [markdown]
# ### Trading

# %% [markdown]
# ##### Subscription to port:7010

# %%
import numpy as np
df = pd.DataFrame()
## warm up upto preprocessing
#final=pd.DataFrame()
money = 120000
buy_cover_order = conn.create_order('MKT',400, 'Buy')
sell_Short_order = conn.create_order('MKT',400, 'Sell')
#window=10
#for _ in range(window):
while True:
    #iterations += 1
    # after forwarder's start
    ml=socket_sub.recv_string()
    sym,close,price,km,arima,UD,LSTM = ml.split()
    dt = datetime.datetime.now()
    df = df.append(pd.DataFrame({'close': float(close),'price': float(price),'km': float(km),'arima': float(arima),'LSTM':float(LSTM)},index=[dt]))
    
    global money
    global request_id
    
    value=float(df.close.tail(1))
        
    #if df.close>df.km and df.arima>df.arima.shift(1) and df.LSTM>df.LSTM.shift(1):
    if np.where(df.price.tail(1)>df.km.tail(1),1,0)==1 and np.where(df.close.tail(1)>df.arima.shift(1).tail(1),1,0)==1:
        
        if money==120000:
            print('400 shares cost %s USD, I have %s USD, so .. '% (400 * value, money))
            print('I buy!')
            conn.place_order(spy_contract, buy_cover_order)
            money = money - 400*value
        if  400* value> money:
            print('I quit')
            conn.cancel_market_data(request_id)
    
    if np.where(df.price.tail(1)<df.km.tail(1),1,0)==1 and np.where(df.km.tail(1)<df.arima.shift(1).tail(1),1,0)==1:
        print('I sell!')
        conn.place_order(spy_contract,sell_Short_order)
        #money = money - 400* value
        money = 120000

    if np.where(df.price.tail(1)<df.km.tail(1),1,0)==1 and np.where(df.close.tail(1)<df.arima.shift(1).tail(1),1,0)==1:
        
        if money==120000:
            print('400 shares cost %s USD, I have %s USD' % (400* value, money))
            print('I short!')
            conn.place_order(spy_contract,sell_Short_order)
            money = money - 400*value
        if 400 * value>money:
            print('I quit')
            conn.cancel_market_data(request_id)
    
    #if df.close<df.km and df.arima>df.arima.shift(1) and df.LSTM>df.LSTM.shift(1):
    if np.where(df.price.tail(1)>df.km.tail(1),1,0)==1 and np.where(df.km.tail(1)>df.arima.shift(1).tail(1),1,0)==1:
        print('I cover!')
        conn.place_order(spy_contract,buy_cover_order)
        money = 120000
      
    df['money']=money
    print(df.tail(1))
# Out:
#                                 LSTM       arima   close          km  \
# 2017-09-14 22:15:31.941448 -0.277956  250.025002  250.09  250.060838
#
#                                  price   money
# 2017-09-14 22:15:31.941448  250.099003  120000
# 400 shares cost 100036.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima   close          km   money  \
# 2017-09-14 22:15:31.948767 -0.522977  250.025002  250.09  250.064114  120000
#
#                                  price
# 2017-09-14 22:15:31.948767  250.097025
# 400 shares cost 100042.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                               LSTM       arima    close          km   money  \
# 2017-09-14 22:15:31.959650 -0.2241  250.025002  250.105  250.067503  120000
#
#                                  price
# 2017-09-14 22:15:31.959650  250.101488
# 400 shares cost 100042.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:15:31.968153 -0.380319  250.025002  250.105  250.070654  120000
#
#                                 price
# 2017-09-14 22:15:31.968153  250.10237
# 400 shares cost 100046.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:15:31.976729 -0.334669  250.025002  250.115  250.074958  120000
#
#                                 price
# 2017-09-14 22:15:31.976729  250.11763
# 400 shares cost 100046.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                LSTM       arima    close          km   money  \
# 2017-09-14 22:15:31.984822 -0.44004  250.035002  250.115  250.078981  120000
#
#                                 price
# 2017-09-14 22:15:31.984822  250.11905
# Server Error: Can't find EId with tickerId:1
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100050.0 USD, I have 120000 USD, so ..
# I buy!Server Error: Can't find EId with tickerId:1
#
# Server Error: Can't find EId with tickerId:1
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:15:31.993015 -0.263193  250.035002  250.125  250.082804  120000
#
#                                 price
# 2017-09-14 22:15:31.993015  250.12095
# 400 shares cost 100050.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:15:32.003786 -0.198893  250.045002  250.125  250.086216  120000
#
#                                  price
# 2017-09-14 22:15:32.003786  250.120498
# 400 shares cost 100050.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:15:32.011580 -0.141805  250.045002  250.125  250.089303  120000
#
#                                  price
# 2017-09-14 22:15:32.011580  250.120498
# 400 shares cost 100050.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:15:32.019168 -0.016806  250.045002  250.125  250.092095  120000
#
#                                  price
# 2017-09-14 22:15:32.019168  250.120498
# 400 shares cost 100050.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:15:32.027497 -0.002515  250.045002  250.125  250.094581  120000
#
#                                  price
# 2017-09-14 22:15:32.027497  250.120065
# Server Error: Can't find EId with tickerId:1
# Server Error: Can't find EId with tickerId:1
# Server Error: Can't find EId with tickerId:1
# Server Error: Can't find EId with tickerId:1
# Server Error: Can't find EId with tickerId:1
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88221.71 CAD] is insufficient to cover the Initial Margin requirement of [110424.73 CAD]
#
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88221.71 CAD] is insufficient to cover the Initial Margin requirement of [110424.73 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88221.71 CAD] is insufficient to cover the Initial Margin requirement of [110424.73 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88221.71 CAD] is insufficient to cover the Initial Margin requirement of [110424.73 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88221.71 CAD] is insufficient to cover the Initial Margin requirement of [110424.73 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88221.71 CAD] is insufficient to cover the Initial Margin requirement of [110424.73 CAD]
#
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88221.71 CAD] is insufficient to cover the Initial Margin requirement of [110424.73 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88221.71 CAD] is insufficient to cover the Initial Margin requirement of [110424.73 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88221.71 CAD] is insufficient to cover the Initial Margin requirement of [110424.73 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88221.71 CAD] is insufficient to cover the Initial Margin requirement of [110424.73 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88221.71 CAD] is insufficient to cover the Initial Margin requirement of [110424.73 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88221.71 CAD] is insufficient to cover the Initial Margin requirement of [110424.73 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88221.71 CAD] is insufficient to cover the Initial Margin requirement of [110424.73 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88221.71 CAD] is insufficient to cover the Initial Margin requirement of [110424.73 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88221.71 CAD] is insufficient to cover the Initial Margin requirement of [110424.73 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88221.71 CAD] is insufficient to cover the Initial Margin requirement of [110424.73 CAD]
#
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88221.71 CAD] is insufficient to cover the Initial Margin requirement of [110424.73 CAD]
#
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88221.71 CAD] is insufficient to cover the Initial Margin requirement of [110424.73 CAD]
#
#     Filled: 0, Status: Inactive
# 400 shares cost 100050.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:15:32.817924  0.003212  250.045002  250.125  250.096829  120000
#
#                                 price
# 2017-09-14 22:15:32.817924  250.12006
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100050.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:15:33.977536  0.003909  250.045002  250.125  250.098866  120000
#
#                                 price
# 2017-09-14 22:15:33.977536  250.12009
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100052.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima   close          km   money  \
# 2017-09-14 22:15:35.170441  0.022347  250.045002  250.13  250.101653  120000
#
#                              price
# 2017-09-14 22:15:35.170441  250.13
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100052.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima   close          km   money  \
# 2017-09-14 22:15:36.348699 -0.025344  250.045002  250.13  250.104174  120000
#
#                              price
# 2017-09-14 22:15:36.348699  250.13
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100054.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:15:37.519279  0.041638  250.045002  250.135  250.106579  120000
#
#                                  price
# 2017-09-14 22:15:37.519279  250.131304
# Server Error: Can't find EId with tickerId:1
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88218.33 CAD] is insufficient to cover the Initial Margin requirement of [110418.43 CAD]
#
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88218.33 CAD] is insufficient to cover the Initial Margin requirement of [110418.43 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88218.33 CAD] is insufficient to cover the Initial Margin requirement of [110418.43 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88218.33 CAD] is insufficient to cover the Initial Margin requirement of [110418.43 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88218.33 CAD] is insufficient to cover the Initial Margin requirement of [110418.43 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88218.33 CAD] is insufficient to cover the Initial Margin requirement of [110418.43 CAD]
#
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88218.33 CAD] is insufficient to cover the Initial Margin requirement of [110418.43 CAD]
#
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88218.33 CAD] is insufficient to cover the Initial Margin requirement of [110418.43 CAD]
#
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88218.33 CAD] is insufficient to cover the Initial Margin requirement of [110418.43 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88218.33 CAD] is insufficient to cover the Initial Margin requirement of [110418.43 CAD]
#
#     Filled: 0, Status: Inactive
# 400 shares cost 100054.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:15:38.743969 -0.000099  250.045002  250.135  250.109504  120000
#
#                                  price
# 2017-09-14 22:15:38.743969  250.139177
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100054.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:15:39.930799  0.014914  250.045002  250.135  250.112151  120000
#
#                                  price
# 2017-09-14 22:15:39.930799  250.139177
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100054.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:15:41.144773  0.000633  250.045002  250.135  250.114547  120000
#
#                                  price
# 2017-09-14 22:15:41.144773  250.139177
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100052.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                LSTM       arima   close          km   money  \
# 2017-09-14 22:15:42.332701 -0.00689  250.045002  250.13  250.116635  120000
#
#                                  price
# 2017-09-14 22:15:42.332701  250.138354
# Server Error: Can't find EId with tickerId:1
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88203.61 CAD] is insufficient to cover the Initial Margin requirement of [110409.96 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88203.61 CAD] is insufficient to cover the Initial Margin requirement of [110409.96 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88203.61 CAD] is insufficient to cover the Initial Margin requirement of [110409.96 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88203.61 CAD] is insufficient to cover the Initial Margin requirement of [110409.96 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88203.61 CAD] is insufficient to cover the Initial Margin requirement of [110409.96 CAD]
#
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88203.61 CAD] is insufficient to cover the Initial Margin requirement of [110409.96 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88203.61 CAD] is insufficient to cover the Initial Margin requirement of [110409.96 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88203.61 CAD] is insufficient to cover the Initial Margin requirement of [110409.96 CAD]
#
#     Filled: 0, Status: Inactive
# 400 shares cost 100052.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima   close         km   money  \
# 2017-09-14 22:15:43.552959  0.036302  250.045002  250.13  250.11758  120000
#
#                                  price
# 2017-09-14 22:15:43.552959  250.128415
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100050.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:15:44.719378  0.003683  250.045002  250.125  250.118035  120000
#
#                                  price
# 2017-09-14 22:15:44.719378  250.124208
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100050.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:15:45.915472  0.043537  250.045002  250.125  250.118065  120000
#
#                                  price
# 2017-09-14 22:15:45.915472  250.120192
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100050.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:15:47.113521  0.031335  250.045002  250.125  250.118092  120000
#
#                                  price
# 2017-09-14 22:15:47.113521  250.120192
# Server Error: Can't find EId with tickerId:1
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88207.22 CAD] is insufficient to cover the Initial Margin requirement of [110413.57 CAD]
#
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88207.22 CAD] is insufficient to cover the Initial Margin requirement of [110413.57 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88207.22 CAD] is insufficient to cover the Initial Margin requirement of [110413.57 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88207.22 CAD] is insufficient to cover the Initial Margin requirement of [110413.57 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88207.22 CAD] is insufficient to cover the Initial Margin requirement of [110413.57 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88207.22 CAD] is insufficient to cover the Initial Margin requirement of [110413.57 CAD]
#
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88207.22 CAD] is insufficient to cover the Initial Margin requirement of [110413.57 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88207.22 CAD] is insufficient to cover the Initial Margin requirement of [110413.57 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88207.22 CAD] is insufficient to cover the Initial Margin requirement of [110413.57 CAD]
#
#     Filled: 0, Status: Inactive
# 400 shares cost 100050.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:15:48.313567  0.045683  250.045002  250.125  250.118117  120000
#
#                                  price
# 2017-09-14 22:15:48.313567  250.120192
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100050.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close         km   money  \
# 2017-09-14 22:15:49.488052  0.055635  250.045002  250.125  250.11814  120000
#
#                                  price
# 2017-09-14 22:15:49.488052  250.120205
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100050.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:15:50.686840  0.058294  250.045002  250.125  250.118164  120000
#
#                                  price
# 2017-09-14 22:15:50.686840  250.120238
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100050.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:15:51.855939  0.058662  250.045002  250.125  250.118185  120000
#
#                                 price
# 2017-09-14 22:15:51.855939  250.12023
# Server Error: Can't find EId with tickerId:1
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88209.17 CAD] is insufficient to cover the Initial Margin requirement of [110413.57 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88209.17 CAD] is insufficient to cover the Initial Margin requirement of [110413.57 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88209.17 CAD] is insufficient to cover the Initial Margin requirement of [110413.57 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88209.17 CAD] is insufficient to cover the Initial Margin requirement of [110413.57 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88209.17 CAD] is insufficient to cover the Initial Margin requirement of [110413.57 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88209.17 CAD] is insufficient to cover the Initial Margin requirement of [110413.57 CAD]
#
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88209.17 CAD] is insufficient to cover the Initial Margin requirement of [110413.57 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88209.17 CAD] is insufficient to cover the Initial Margin requirement of [110413.57 CAD]
#
#     Filled: 0, Status: Inactive
# 400 shares cost 100050.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:15:53.038499  0.058807  250.045002  250.125  250.118202  120000
#
#                                  price
# 2017-09-14 22:15:53.038499  250.120197
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100050.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:15:54.261656  0.058652  250.045002  250.125  250.118217  120000
#
#                                  price
# 2017-09-14 22:15:54.261656  250.120199
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100050.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:15:55.420393  0.058608  250.045002  250.125  250.118243  120000
#
#                                  price
# 2017-09-14 22:15:55.420393  250.120328
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100050.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:15:56.606028  0.058688  250.045002  250.125  250.118268  120000
#
#                                 price
# 2017-09-14 22:15:56.606028  250.12034
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100050.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:15:57.783885  0.058537  250.045002  250.125  250.118266  120000
#
#                                  price
# 2017-09-14 22:15:57.783885  250.120105
# Server Error: Can't find EId with tickerId:1
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88207.88 CAD] is insufficient to cover the Initial Margin requirement of [110416.29 CAD]
#
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88207.88 CAD] is insufficient to cover the Initial Margin requirement of [110416.29 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88207.88 CAD] is insufficient to cover the Initial Margin requirement of [110416.29 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88207.88 CAD] is insufficient to cover the Initial Margin requirement of [110416.29 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88207.88 CAD] is insufficient to cover the Initial Margin requirement of [110416.29 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88207.88 CAD] is insufficient to cover the Initial Margin requirement of [110416.29 CAD]
#
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88207.88 CAD] is insufficient to cover the Initial Margin requirement of [110416.29 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88207.88 CAD] is insufficient to cover the Initial Margin requirement of [110416.29 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88207.88 CAD] is insufficient to cover the Initial Margin requirement of [110416.29 CAD]
#
#     Filled: 0, Status: Inactive
# 400 shares cost 100052.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima   close          km   money  \
# 2017-09-14 22:15:58.980889  0.058529  250.045002  250.13  250.119206  120000
#
#                              price
# 2017-09-14 22:15:58.980889  250.13
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100052.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima   close          km   money  \
# 2017-09-14 22:16:00.142824  0.013619  250.045002  250.13  250.120057  120000
#
#                              price
# 2017-09-14 22:16:00.142824  250.13
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100054.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:16:01.330749  0.043968  250.040002  250.135  250.121004  120000
#
#                                  price
# 2017-09-14 22:16:01.330749  250.131875
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100054.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:16:02.493902  0.001628  250.040002  250.135  250.122592  120000
#
#                                  price
# 2017-09-14 22:16:02.493902  250.139511
# Server Error: Can't find EId with tickerId:1
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88211.26 CAD] is insufficient to cover the Initial Margin requirement of [110416.73 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88211.26 CAD] is insufficient to cover the Initial Margin requirement of [110416.73 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88211.26 CAD] is insufficient to cover the Initial Margin requirement of [110416.73 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88211.26 CAD] is insufficient to cover the Initial Margin requirement of [110416.73 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88211.26 CAD] is insufficient to cover the Initial Margin requirement of [110416.73 CAD]
#
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88211.26 CAD] is insufficient to cover the Initial Margin requirement of [110416.73 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88211.26 CAD] is insufficient to cover the Initial Margin requirement of [110416.73 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88211.26 CAD] is insufficient to cover the Initial Margin requirement of [110416.73 CAD]
#
#     Filled: 0, Status: Inactive
# 400 shares cost 100054.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:16:03.944837 -0.048994  250.035002  250.135  250.124032  120000
#
#                                  price
# 2017-09-14 22:16:03.944837  250.139511
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100054.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:16:05.384047 -0.079895  250.035002  250.135  250.125337  120000
#
#                                  price
# 2017-09-14 22:16:05.384047  250.139511
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100054.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:16:06.764757 -0.158232  250.035002  250.135  250.126537  120000
#
#                                  price
# 2017-09-14 22:16:06.764757  250.139693
# Server Error: Can't find EId with tickerId:1
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88201.06 CAD] is insufficient to cover the Initial Margin requirement of [110412.78 CAD]
#
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88201.06 CAD] is insufficient to cover the Initial Margin requirement of [110412.78 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88201.06 CAD] is insufficient to cover the Initial Margin requirement of [110412.78 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88201.06 CAD] is insufficient to cover the Initial Margin requirement of [110412.78 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88201.06 CAD] is insufficient to cover the Initial Margin requirement of [110412.78 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88201.06 CAD] is insufficient to cover the Initial Margin requirement of [110412.78 CAD]
#
#     Filled: 0, Status: Inactive
# 400 shares cost 100054.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:16:08.004292 -0.164933  250.035002  250.135  250.127621  120000
#
#                                  price
# 2017-09-14 22:16:08.004292  250.139672
# Server Error: Can't find EId with tickerId:1
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88201.06 CAD] is insufficient to cover the Initial Margin requirement of [110412.78 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88201.06 CAD] is insufficient to cover the Initial Margin requirement of [110412.78 CAD]
#
#     Filled: 0, Status: Inactive
# 400 shares cost 100054.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:16:09.284165 -0.166073  250.035002  250.135  250.128502  120000
#
#                                  price
# 2017-09-14 22:16:09.284165  250.138613
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100054.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:16:10.493861 -0.164071  250.035002  250.135  250.129291  120000
#
#                                 price
# 2017-09-14 22:16:10.493861  250.13851
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100054.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:16:11.915377 -0.163691  250.035002  250.135  250.129891  120000
#
#                                  price
# 2017-09-14 22:16:11.915377  250.137306
# Server Error: Can't find EId with tickerId:1
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88194.37 CAD] is insufficient to cover the Initial Margin requirement of [110410.97 CAD]
#
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88194.37 CAD] is insufficient to cover the Initial Margin requirement of [110410.97 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88194.37 CAD] is insufficient to cover the Initial Margin requirement of [110410.97 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88194.37 CAD] is insufficient to cover the Initial Margin requirement of [110410.97 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88194.37 CAD] is insufficient to cover the Initial Margin requirement of [110410.97 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88194.37 CAD] is insufficient to cover the Initial Margin requirement of [110410.97 CAD]
#
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88194.37 CAD] is insufficient to cover the Initial Margin requirement of [110410.97 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88194.37 CAD] is insufficient to cover the Initial Margin requirement of [110410.97 CAD]
#
#     Filled: 0, Status: Inactive
# 400 shares cost 100054.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:16:13.399276 -0.160794  250.030002  250.135  250.130106  120000
#
#                                  price
# 2017-09-14 22:16:13.399276  250.133798
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100054.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close         km   money  \
# 2017-09-14 22:16:14.826305 -0.160567  250.030002  250.135  250.13051  120000
#
#                                  price
# 2017-09-14 22:16:14.826305  250.135976
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100054.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:16:16.075219 -0.229669  250.025002  250.135  250.131139  120000
#
#                                  price
# 2017-09-14 22:16:16.075219  250.138731
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100054.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close         km   money  \
# 2017-09-14 22:16:17.329323 -0.243497  250.025002  250.135  250.13173  120000
#
#                                  price
# 2017-09-14 22:16:17.329323  250.138937
# Server Error: Can't find EId with tickerId:1
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88211.26 CAD] is insufficient to cover the Initial Margin requirement of [110416.73 CAD]
#
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88211.26 CAD] is insufficient to cover the Initial Margin requirement of [110416.73 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88211.26 CAD] is insufficient to cover the Initial Margin requirement of [110416.73 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88211.26 CAD] is insufficient to cover the Initial Margin requirement of [110416.73 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88211.26 CAD] is insufficient to cover the Initial Margin requirement of [110416.73 CAD]
#
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88211.26 CAD] is insufficient to cover the Initial Margin requirement of [110416.73 CAD]
#
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88211.26 CAD] is insufficient to cover the Initial Margin requirement of [110416.73 CAD]
#
#     Filled: 0, Status: Inactive
# Order: BUY 400 SPY
#     Filled: 0, Status: Inactive
# Server Error: Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [88211.26 CAD] is insufficient to cover the Initial Margin requirement of [110416.73 CAD]
#
#     Filled: 0, Status: Inactive
# 400 shares cost 100054.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:16:18.615287 -0.322134  250.050002  250.135  250.132236  120000
#
#                                  price
# 2017-09-14 22:16:18.615287  250.138826
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100054.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:16:19.837590 -0.324169  250.050002  250.135  250.132678  120000
#
#                                  price
# 2017-09-14 22:16:19.837590  250.138638
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100054.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:16:21.053665 -0.188178  250.075002  250.135  250.133047  120000
#
#                                  price
# 2017-09-14 22:16:21.053665  250.138333
# Server Error: Can't find EId with tickerId:1
# 400 shares cost 100054.0 USD, I have 120000 USD, so ..
# I buy!
# I quit
# I cover!
#                                 LSTM       arima    close          km   money  \
# 2017-09-14 22:16:22.284914 -0.170131  250.075002  250.135  250.133407  120000
#
#                                  price
# 2017-09-14 22:16:22.284914  250.138602
# Server Error: Can't find EId with tickerId:1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-74-fa51c0fadc48> in <module>()
#      11     #iterations += 1
#      12     # after forwarder's start
# ---> 13     ml=socket_sub.recv_string()
#      14     sym,close,price,km,arima,UD,LSTM = ml.split()
#      15     dt = datetime.datetime.now()
#
# /home/octo/anaconda2/envs/carnd-term1/lib/python3.5/site-packages/zmq/sugar/socket.py in recv_string(self, flags, encoding)
#     455             The Python unicode string that arrives as encoded bytes.
#     456         """
# --> 457         msg = self.recv(flags=flags)
#     458         return self._deserialize(msg, lambda buf: buf.decode(encoding))
#     459
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq/backend/cython/socket.c:7683)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq/backend/cython/socket.c:7460)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy (zmq/backend/cython/socket.c:2344)()
#
# /home/octo/anaconda2/envs/carnd-term1/lib/python3.5/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc (zmq/backend/cython/socket.c:9621)()
#
# KeyboardInterrupt:
